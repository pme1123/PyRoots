# %% [markdown]
# # Test pyroots functions

# %% [markdown]
# Load a test image and libraries
# Libraries are:
#
# __all__ = ['noise_removal', 'dirt_removal',
# 		   '_percentile_filter', 'diameter_filter', 'length_width_filter',
# 	   	   'summarize_geometry', 'bin_by_diameter',
# 	   	   '_axis_length', 'skeleton_with_distance',
# 	   	   'img_split', 'circle_mask',
# 	   	   'multi_image_plot', 'random_blobs',
# 	   	   'pyroots_analysis', 'image_loop']

# %%
# %matplotlib inline

import pyroots as pr
from skimage import io
from matplotlib import pyplot

dir_in = "/home/patrick/Cloud/Codes/pyroots/pyroots/sample_images/"
file_in = "hyphae_500x500.tif"
image = io.imread(dir_in + file_in)[:,:,0:3]

pyplot.imshow(image)

# %% [markdown]
# Test multi image plot using random_blobs, img_split

# %%
bands = pr.img_split(image)
blobs = pr.random_blobs(n = 10, size = 1)
pr.multi_image_plot(bands.extend(blobs), ['r','g','b','blobs'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-3285cc7ae1f0> in <module>()
#       1 bands = pr.img_split(image)
#       2 blobs = pr.random_blobs(n = 10, size = 1)
# ----> 3 pr.multi_image_plot(bands.extend(blobs), ['r','g','b','blobs'])
#
# AttributeError: 'tuple' object has no attribute 'extend'
